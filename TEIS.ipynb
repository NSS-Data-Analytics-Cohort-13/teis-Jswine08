# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bdi2 = pd.read_csv('../projects/teis-Jswine08/Data/NSS data_BDI2 scores_20200101-20230131_20241106 (1).csv')
bdi2
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\3284343376.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   bdi2 = pd.read_csv('../projects/teis-Jswine08/Data/NSS data_BDI2 scores_20200101-20230131_20241106 (1).csv')
#         StudentID  studentAssessmentID  resultStudentDomainID  \
# 0         2224693              8625078              138104116
# 1         2224693              8625078              138104117
# 2         2224693              8625078              138104118
# 3         2224693              8625078              138104119
# 4         2224693              8625078              138104120
# ...           ...                  ...                    ...
# 325681    2319431              8761874              140602545
# 325682    2319431              8761874              140602546
# 325683    2319431              8761874              140602547
# 325684    2319431              8761874              140602548
# ...

# %%
bdi2_data = bdi2[['Student TEIDS ID','domainID','domainText','testDate','rawScore','scaledScore','DQScore','PRScore','NceScore','TScore','ZScore','AEScore']]
bdi2_data
# Out:
#        Student TEIDS ID  domainID                     domainText   testDate  \
# 0                 52101         7                      Self-Care  2/25/2022
# 1                 52101        10              Adult Interaction  2/25/2022
# 2                 52101        12   Self-Concept and Social Role  2/25/2022
# 3                 52101        14        Receptive Communication  2/25/2022
# 4                 52101        15       Expressive Communication  2/25/2022
# ...                 ...       ...                            ...        ...
# 325681              NaN        13                  Communication        NaN
# 325682              NaN        16                          Motor        NaN
# 325683              NaN        19               Perceptual Motor        NaN
# 325684              NaN        20                      Cognitive        NaN
# 325685              NaN        22  Reasoning and Academic Skills        NaN
#
# ...

# %%
df_bdi2_data = bdi2[['Student TEIDS ID','domainID','domainText','testDate','rawScore','DQScore','ZScore']]
df_bdi2_data
# Out:
#        Student TEIDS ID  domainID                     domainText   testDate  \
# 0                 52101         7                      Self-Care  2/25/2022
# 1                 52101        10              Adult Interaction  2/25/2022
# 2                 52101        12   Self-Concept and Social Role  2/25/2022
# 3                 52101        14        Receptive Communication  2/25/2022
# 4                 52101        15       Expressive Communication  2/25/2022
# ...                 ...       ...                            ...        ...
# 325681              NaN        13                  Communication        NaN
# 325682              NaN        16                          Motor        NaN
# 325683              NaN        19               Perceptual Motor        NaN
# 325684              NaN        20                      Cognitive        NaN
# 325685              NaN        22  Reasoning and Academic Skills        NaN
#
#         rawScore  DQScore  ZScore
# ...

# %%
df_bdi2_data = bdi2[['Student TEIDS ID','domainText','testDate','rawScore','DQScore','ZScore']]
df_bdi2_data

score_columns = ['rawScore', 'DQScore', 'ZScore']
#Melt the DataFrame to long format
df_melted = df_bdi2_data.melt(id_vars=["Student TEIDS ID", "domainText"], 
                              value_vars=score_columns, 
                              var_name="ScoreType", 
                              value_name="Score")
df_melted["ColumnName"] = df_melted["domainText"] + " " + df_melted["ScoreType"]
#Pivot the data to have 'Student TEIDS ID' as rows and dynamic columns
df_pivoted = df_melted.pivot_table(index="Student TEIDS ID", 
                                   columns="ColumnName", 
                                   values="Score", 
                                   aggfunc="first")
df_pivoted.columns = df_pivoted.columns.get_level_values(0)
df_result = df_pivoted.reset_index()
df_result
# Out:
# ColumnName Student TEIDS ID  Adaptive DQScore  Adaptive ZScore  \
# 0                     52101              80.0            -1.33
# 1                    416571              65.0            -2.33
# 2                    419105              95.0            -0.33
# 3                    419833             105.0             0.33
# 4                    423227              65.0            -2.33
# ...                     ...               ...              ...
# 17353                571437              90.0            -0.67
# 17354                580447              60.0            -2.67
# 17355                580709              70.0            -2.00
# 17356                650159              93.0            -0.47
# 17357               xxxxxxx              90.0            -0.67
#
# ColumnName  Adaptive rawScore  Adult Interaction ZScore  \
# 0                         2.0                      1.67
# 1                        33.0                     -1.67
# ...

# %%
bdi3 = pd.read_csv('../projects/teis-Jswine08/Data/NSS data_BDI3 Scores 20230101 20240630_Compiled_20241107.xlsx - BDI3 Scores 20230101 20240630_C.csv')
bdi3
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\3847495039.py:1: DtypeWarning: Columns (9,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   bdi3 = pd.read_csv('../projects/teis-Jswine08/Data/NSS data_BDI3 Scores 20230101 20240630_Compiled_20241107.xlsx - BDI3 Scores 20230101 20240630_C.csv')
#        Last Name  First Name  Gender  Date of Birth  \
# 0            NaN         NaN     NaN            NaN
# 1            NaN         NaN     NaN            NaN
# 2            NaN         NaN     NaN            NaN
# 3            NaN         NaN     NaN            NaN
# 4            NaN         NaN     NaN            NaN
# ...          ...         ...     ...            ...
# 34974        NaN         NaN     NaN            NaN
# 34975        NaN         NaN     NaN            NaN
# 34976        NaN         NaN     NaN            NaN
# 34977        NaN         NaN     NaN            NaN
# 34978        NaN         NaN     NaN            NaN
#
# ...

# %%
bdi3_new_columns = bdi3[['TEIDS Child ID','Motor-Gross Motor RS', 'Adaptive-Self Care RS', 'Motor-Fine Motor RS', 'Motor-Perceptual Motor RS', 'Adaptive-Personal Responsibility RS', 'Social Emotional-Adult Interaction RS', 'Social Emotional-Peer Interaction RS','Social Emotional-Self Concept / Social Role RS','Communication-Receptive Communication RS','Communication-Expressive Communication RS','Cognitive-Attention and Memory RS','Cognitive-Reasoning / Academic Skills RS','Cognitive-Perception and Concepts RS', 'TEIDS Child ID', 'Motor-Fine Motor Date of Testing', 'BDI-3 Total Developmental Quotient', 'Adaptive Z-Score', 'Social-Emotional Z-Score', 'Communication Z-Score', 'Motor Z-Score', 'Cognitive Z-Score', 'Adaptive-Self Care Z-Score', 'Adaptive-Personal Responsibility Z-Score', 'Social Emotional-Adult Interaction Z-Score', 'Social Emotional-Peer Interaction Z-Score', 'Social Emotional-Self Concept / Social Role Z-Score', 'Communication-Receptive Communication Z-Score', 'Communication-Expressive Communication Z-Score', 'Motor-Gross Motor Z-Score', 'Motor-Fine Motor Z-Score', 'Motor-Perceptual Motor Z-Score', 'Cognitive-Attention and Memory Z-Score', 'Cognitive-Reasoning / Academic Skills Z-Score', 'Cognitive-Perception and Concepts Z-Score', 'Cognitive-Perception and Concepts Date of Testing']]

# %%
bdi3_new_columns
# Out:
#        TEIDS Child ID  Motor-Gross Motor RS  Adaptive-Self Care RS  \
# 0            474074.0                  64.0                   38.0
# 1            474186.0                  65.0                   51.0
# 2            474641.0                  67.0                   39.0
# 3            474848.0                  58.0                   27.0
# 4            474967.0                  50.0                   30.0
# ...               ...                   ...                    ...
# 34974             NaN                  59.0                   32.0
# 34975             NaN                  54.0                   25.0
# 34976             NaN                  61.0                   34.0
# 34977             NaN                  43.0                   23.0
# 34978             NaN                  52.0                   30.0
#
#        Motor-Fine Motor RS  Motor-Perceptual Motor RS  \
# 0                     34.0                       11.0
# ...

# %%
eco = pd.read_csv('../projects/teis-Jswine08/Data/NSS_ECO Data Ind 3 FFY 2023-24 20241211.xlsx - ECO with Exit23-24 .csv')
eco
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\638575659.py:1: DtypeWarning: Columns (89,93,94,95,98,102,106,107,108,109,110,128,129,136,139) have mixed types. Specify dtype option on import or set low_memory=False.
#   eco = pd.read_csv('../projects/teis-Jswine08/Data/NSS_ECO Data Ind 3 FFY 2023-24 20241211.xlsx - ECO with Exit23-24 .csv')
#      DISTRICT  CHILD_ID  Child ID_ Assessement point ECO_Entry_DATE  \
# 0          GN    473991                          NaN       1/7/2020
# 1          GN    474186                          NaN      2/13/2020
# 2          ET    474575                          NaN      1/17/2020
# 3          NW    474623                          NaN      1/22/2019
# 4          SW    474848                          NaN       7/9/2021
# ...       ...       ...                          ...            ...
# 9994       SC    579717                          NaN            NaN
# 9995       SC    579729                          NaN            NaN
# ...

# %%
df_eco_data = eco[['CHILD_ID','ECO_Entry_DATE','ECO_Exit_DATE','Initial IFSP Date','Exit Date \nOr end of FY','TEIDS\nECO_Entry_DATE','AEPSi\nECO_Entry_DATE','AEPSi \nECO_Exit_DATE','BDI 3\nECO_Entry_DATE','BDI 3\nECO_Exit_DATE','BDI2 Entry Date', 'More than 182 days btwn ECO (continued) and Exit?', 'Days btw I-IFSP to Exit ECO']]

# %%
df_eco_data
# Out:
#       CHILD_ID ECO_Entry_DATE ECO_Exit_DATE Initial IFSP Date  \
# 0       473991       1/7/2020    12/27/2022          1/7/2020
# 1       474186      2/13/2020    10/26/2023         1/14/2020
# 2       474575      1/17/2020     7/29/2020         1/17/2020
# 3       474623      1/22/2019    12/16/2022         1/22/2020
# 4       474848       7/9/2021      8/4/2023          7/9/2021
# ...        ...            ...           ...               ...
# 9994    579717            NaN           NaN         5/29/2024
# 9995    579729            NaN           NaN         6/13/2024
# 9996    580243            NaN           NaN         6/17/2024
# 9997    580375            NaN           NaN          6/5/2024
# 9998    580840            NaN           NaN          6/4/2024
#
#      Exit Date \nOr end of FY TEIDS\nECO_Entry_DATE AEPSi\nECO_Entry_DATE  \
# 0                    9/8/2023              1/7/2020             2/18/2020
# ...

# %%
df_eco_data['ECO_Entry_DATE'] = pd.to_datetime(df_eco_data['ECO_Entry_DATE'])
df_eco_data['BDI 3\nECO_Entry_DATE'] = pd.to_datetime(df_eco_data['BDI 3\nECO_Entry_DATE'])
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\1809967335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eco_data['ECO_Entry_DATE'] = pd.to_datetime(df_eco_data['ECO_Entry_DATE'])
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\1809967335.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eco_data['BDI 3\nECO_Entry_DATE'] = pd.to_datetime(df_eco_data['BDI 3\nECO_Entry_DATE'])

# %%
df_eco_data = df_eco_data.dropna(axis=0, subset=['BDI 3\nECO_Exit_DATE'])
df_eco_data
# Out:
#       CHILD_ID ECO_Entry_DATE ECO_Exit_DATE Initial IFSP Date  \
# 1       474186     2020-02-13    10/26/2023         1/14/2020
# 4       474848     2021-07-09      8/4/2023          7/9/2021
# 5       474967     2020-01-31     7/31/2023         1/31/2020
# 6       475636     2020-09-03     7/19/2023          9/3/2020
# 7       475907     2020-02-20    11/15/2023         2/20/2020
# ...        ...            ...           ...               ...
# 9638    569363     2023-12-14    10/30/2024         1/26/2024
# 9646    569449     2023-12-21    10/31/2024         1/25/2024
# 9688    570207            NaT           NaN          2/2/2024
# 9692    570254     2024-01-04    10/23/2024         2/12/2024
# 9714    570632     2024-01-11    10/29/2024          2/7/2024
#
#      Exit Date \nOr end of FY TEIDS\nECO_Entry_DATE AEPSi\nECO_Entry_DATE  \
# 1                   11/2/2023             2/13/2020             2/13/2020
# ...

# %%
dates_needed = df_eco_data[['CHILD_ID', 'ECO_Entry_DATE', 'ECO_Exit_DATE', 'Initial IFSP Date', 'TEIDS\nECO_Entry_DATE', 'BDI 3\nECO_Entry_DATE', 'BDI 3\nECO_Exit_DATE', 'BDI2 Entry Date']]
dates_needed
# Out:
#       CHILD_ID ECO_Entry_DATE ECO_Exit_DATE Initial IFSP Date  \
# 1       474186     2020-02-13    10/26/2023         1/14/2020
# 4       474848     2021-07-09      8/4/2023          7/9/2021
# 5       474967     2020-01-31     7/31/2023         1/31/2020
# 6       475636     2020-09-03     7/19/2023          9/3/2020
# 7       475907     2020-02-20    11/15/2023         2/20/2020
# ...        ...            ...           ...               ...
# 9638    569363     2023-12-14    10/30/2024         1/26/2024
# 9646    569449     2023-12-21    10/31/2024         1/25/2024
# 9688    570207            NaT           NaN          2/2/2024
# 9692    570254     2024-01-04    10/23/2024         2/12/2024
# 9714    570632     2024-01-11    10/29/2024          2/7/2024
#
#      TEIDS\nECO_Entry_DATE BDI 3\nECO_Entry_DATE BDI 3\nECO_Exit_DATE  \
# 1                2/13/2020                   NaT           10/26/2023
# 4                 7/9/2021                   NaT             8/4/2023
# ...

# %%
trimmed_dates = df_eco_data[['CHILD_ID', 'ECO_Entry_DATE', 'TEIDS\nECO_Entry_DATE', 'BDI 3\nECO_Entry_DATE', 'BDI 3\nECO_Exit_DATE', 'BDI2 Entry Date']]
trimmed_dates
# Out:
#       CHILD_ID ECO_Entry_DATE TEIDS\nECO_Entry_DATE BDI 3\nECO_Entry_DATE  \
# 1       474186     2020-02-13             2/13/2020                   NaT
# 4       474848     2021-07-09              7/9/2021                   NaT
# 5       474967     2020-01-31             1/31/2020                   NaT
# 6       475636     2020-09-03              9/3/2020                   NaT
# 7       475907     2020-02-20             2/20/2020                   NaT
# ...        ...            ...                   ...                   ...
# 9638    569363     2023-12-14                   NaN            2023-12-14
# 9646    569449     2023-12-21                   NaN            2023-12-21
# 9688    570207            NaT                   NaN                   NaT
# 9692    570254     2024-01-04                   NaN            2024-01-04
# 9714    570632     2024-01-11                   NaN            2024-01-11
#
#      BDI 3\nECO_Exit_DATE BDI2 Entry Date
# ...

# %%
no_nulls_eco_exit['ECO_Entry_DATE'].tolist()

# %% [markdown]
# def dates (date1, date2):
#     comparison= np.where(no_nulls_eco_exit[date1]<no_nulls_eco_exit[date2])
#     return comparison
#
# df1 = dates('BDI2 Entry Date', 'BDI 3\nECO_Entry_DATE')
# df1

# %%
df_eco_data[df_eco_data['CHILD_ID']==473991]
# Out:
#    CHILD_ID ECO_Entry_DATE ECO_Exit_DATE Initial IFSP Date  \
# 0    473991     2020-01-07    12/27/2022          1/7/2020
#
#   Exit Date \nOr end of FY TEIDS\nECO_Entry_DATE AEPSi\nECO_Entry_DATE  \
# 0                 9/8/2023              1/7/2020             2/18/2020
#
#   AEPSi \nECO_Exit_DATE BDI 3\nECO_Entry_DATE BDI 3\nECO_Exit_DATE  \
# 0            11/14/2022                   NaT                  NaN
#
#   BDI2 Entry Date More than 182 days btwn ECO (continued) and Exit?  \
# 0             NaN                                               Yes
#
#    Days btw I-IFSP to Exit ECO
# 0                         1085

# %%
bdi3_new_columns['Cognitive-Perception and Concepts Date of Testing'] = pd.to_datetime(bdi3_new_columns['Cognitive-Perception and Concepts Date of Testing'])
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\2346917800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bdi3_new_columns['Cognitive-Perception and Concepts Date of Testing'] = pd.to_datetime(bdi3_new_columns['Cognitive-Perception and Concepts Date of Testing'])

# %%
bdi3_new_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34979 entries, 0 to 34978
# Data columns (total 36 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   TEIDS Child ID                                       34661 non-null  float64
#  1   Motor-Gross Motor RS                                 34954 non-null  float64
#  2   Adaptive-Self Care RS                                34968 non-null  float64
#  3   Motor-Fine Motor RS                                  34949 non-null  float64
#  4   Motor-Perceptual Motor RS                            17410 non-null  float64
#  5   Adaptive-Personal Responsibility RS                  17421 non-null  float64
#  6   Social Emotional-Adult Interaction RS                34960 non-null  float64
#  7   Social Emotional-Peer Interaction RS                 17418 non-null  float64
# ...

# %%
bdi3_new_columns['Cognitive-Perception and Concepts Date of Testing'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 34979 entries, 0 to 34978
# Series name: Cognitive-Perception and Concepts Date of Testing
# Non-Null Count  Dtype
# --------------  -----
# 34952 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 273.4 KB

# %%
combined = df_result.join(bdi3_new_columns, how='outer')
combined
# Out:
#       Student TEIDS ID  Adaptive DQScore  Adaptive ZScore  Adaptive rawScore  \
# 0                52101              80.0            -1.33                2.0
# 1               416571              65.0            -2.33               33.0
# 2               419105              95.0            -0.33               53.0
# 3               419833             105.0             0.33               57.0
# 4               423227              65.0            -2.33               32.0
# ...                ...               ...              ...                ...
# 34974              NaN               NaN              NaN                NaN
# 34975              NaN               NaN              NaN                NaN
# 34976              NaN               NaN              NaN                NaN
# 34977              NaN               NaN              NaN                NaN
# 34978              NaN               NaN              NaN                NaN
#
# ...

# %% [markdown]
# total_combined = combined.join(trimmed_dates, how='outer')
# total_combined

# %%
total_combined[total_combined['Student TEIDS ID']==474848]

# %%
df_eco_data['Entry Test Date'] = df_eco_data['BDI 3\nECO_Entry_DATE'].where(df_eco_data['BDI 3\nECO_Entry_DATE'] == df_eco_data['ECO_Entry_DATE'], other = df_eco_data['BDI2 Entry Date'])
df_eco_data
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\942801580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eco_data['Entry Test Date'] = df_eco_data['BDI 3\nECO_Entry_DATE'].where(df_eco_data['BDI 3\nECO_Entry_DATE'] == df_eco_data['ECO_Entry_DATE'], other = df_eco_data['BDI2 Entry Date'])
#       CHILD_ID ECO_Entry_DATE ECO_Exit_DATE Initial IFSP Date  \
# 0       473991     2020-01-07    12/27/2022          1/7/2020
# 1       474186     2020-02-13    10/26/2023         1/14/2020
# 2       474575     2020-01-17     7/29/2020         1/17/2020
# 3       474623     2019-01-22    12/16/2022         1/22/2020
# 4       474848     2021-07-09      8/4/2023          7/9/2021
# ...

# %%
subdomain3 = bdi3_new_columns[['Cognitive-Perception and Concepts RS', 'Cognitive-Reasoning / Academic Skills RS', 'Cognitive-Attention and Memory RS', 'Motor-Perceptual Motor RS', 'Motor-Fine Motor RS', 'Motor-Gross Motor RS', 'Communication-Expressive Communication RS', 'Communication-Receptive Communication RS', 'Social Emotional-Self Concept / Social Role RS', 'Social Emotional-Peer Interaction RS', 'Social Emotional-Adult Interaction RS', 'Adaptive-Personal Responsibility RS', 'Adaptive-Self Care RS']]
subdomain3
# Out:
#        Cognitive-Perception and Concepts RS  \
# 0                                      13.0
# 1                                      24.0
# 2                                      26.0
# 3                                      17.0
# 4                                      12.0
# ...                                     ...
# 34974                                  10.0
# 34975                                  10.0
# 34976                                  11.0
# 34977                                   9.0
# 34978                                  12.0
#
#        Cognitive-Reasoning / Academic Skills RS  \
# 0                                          17.0
# 1                                          20.0
# 2                                          22.0
# 3                                          17.0
# 4                                           7.0
# ...                                         ...
# 34974                                       6.0
# ...

# %%
subdomain2 = df_result[['Student TEIDS ID','Self-Care rawScore', 'Adult Interaction rawScore', 'Self-Concept and Social Role rawScore', 'Receptive Communication rawScore', 'Expressive Communication rawScore', 'Gross Motor rawScore', 'Fine Motor rawScore', 'Attention and Memory rawScore', 'Perception and Concepts rawScore', 'Personal Responsibility rawScore', 'Peer Interaction rawScore', 'Perceptual Motor rawScore', 'Reasoning and Academic Skills rawScore']]
subdomain2
# Out:
# ColumnName Student TEIDS ID  Self-Care rawScore  Adult Interaction rawScore  \
# 0                     52101                 2.0                        14.0
# 1                    416571                32.0                        37.0
# 2                    419105                46.0                        44.0
# 3                    419833                47.0                        45.0
# 4                    423227                32.0                        20.0
# ...                     ...                 ...                         ...
# 17353                571437                26.0                        30.0
# 17354                580447                 0.0                         5.0
# 17355                580709                31.0                        30.0
# 17356                650159                30.0                        43.0
# 17357               xxxxxxx                22.0                        32.0
#
# ColumnName  Self-Concept and Social Role rawScore  \
# ...

# %% [markdown]
# no_nulls_eco_exit['Entry Test Date'] = no_nulls_eco_exit['BDI 3\nECO_Entry_DATE'].where(no_nulls_eco_exit['BDI 3\nECO_Entry_DATE'] == no_nulls_eco_exit['ECO_Entry_DATE'], other = no_nulls_eco_exit['BDI2 Entry Date'])

# %%
df_eco_data['Entry Test Date'] = df_eco_data['BDI 3\nECO_Entry_DATE'].where(df_eco_data['BDI 3\nECO_Entry_DATE'] == df_eco_data['ECO_Entry_DATE'], other = df_eco_data['BDI2 Entry Date'])
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\4037188389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eco_data['Entry Test Date'] = df_eco_data['BDI 3\nECO_Entry_DATE'].where(df_eco_data['BDI 3\nECO_Entry_DATE'] == df_eco_data['ECO_Entry_DATE'], other = df_eco_data['BDI2 Entry Date'])

# %%
df_eco_data.dropna(subset=['Entry Test Date'], inplace=True)
df_eco_data
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\196105769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eco_data.dropna(subset=['Entry Test Date'], inplace=True)
#       CHILD_ID ECO_Entry_DATE ECO_Exit_DATE Initial IFSP Date  \
# 4       474848     2021-07-09      8/4/2023          7/9/2021
# 5       474967     2020-01-31     7/31/2023         1/31/2020
# 7       475907     2020-02-20    11/15/2023         2/20/2020
# 8       476193     2020-02-24     2/27/2023         2/24/2020
# 17      478004     2020-03-31      3/9/2023         3/31/2020
# ...        ...            ...           ...               ...
# 9628    569251     2023-12-26     9/25/2024          1/5/2024
# 9638    569363     2023-12-14    10/30/2024         1/26/2024
# ...

# %%
df_eco_data['Exit Test Date'] = df_eco_data['BDI 3\nECO_Exit_DATE'].where(df_eco_data['BDI 3\nECO_Exit_DATE'] == df_eco_data['ECO_Exit_DATE'], other = df_eco_data['BDI 3\nECO_Exit_DATE'])
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\4053215887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eco_data['Exit Test Date'] = df_eco_data['BDI 3\nECO_Exit_DATE'].where(df_eco_data['BDI 3\nECO_Exit_DATE'] == df_eco_data['ECO_Exit_DATE'], other = df_eco_data['BDI 3\nECO_Exit_DATE'])

# %%
df_eco_data
# Out:
#       CHILD_ID ECO_Entry_DATE ECO_Exit_DATE Initial IFSP Date  \
# 4       474848     2021-07-09      8/4/2023          7/9/2021
# 5       474967     2020-01-31     7/31/2023         1/31/2020
# 7       475907     2020-02-20    11/15/2023         2/20/2020
# 8       476193     2020-02-24     2/27/2023         2/24/2020
# 17      478004     2020-03-31      3/9/2023         3/31/2020
# ...        ...            ...           ...               ...
# 9628    569251     2023-12-26     9/25/2024          1/5/2024
# 9638    569363     2023-12-14    10/30/2024         1/26/2024
# 9646    569449     2023-12-21    10/31/2024         1/25/2024
# 9692    570254     2024-01-04    10/23/2024         2/12/2024
# 9714    570632     2024-01-11    10/29/2024          2/7/2024
#
#      Exit Date \nOr end of FY TEIDS\nECO_Entry_DATE AEPSi\nECO_Entry_DATE  \
# 4                  12/13/2023              7/9/2021             7/23/2021
# ...

# %%
df_eco_data[df_eco_data['Days btw I-IFSP to Exit ECO']>180]
# Out:
#       CHILD_ID ECO_Entry_DATE ECO_Exit_DATE Initial IFSP Date  \
# 4       474848     2021-07-09      8/4/2023          7/9/2021
# 5       474967     2020-01-31     7/31/2023         1/31/2020
# 7       475907     2020-02-20    11/15/2023         2/20/2020
# 8       476193     2020-02-24     2/27/2023         2/24/2020
# 17      478004     2020-03-31      3/9/2023         3/31/2020
# ...        ...            ...           ...               ...
# 9628    569251     2023-12-26     9/25/2024          1/5/2024
# 9638    569363     2023-12-14    10/30/2024         1/26/2024
# 9646    569449     2023-12-21    10/31/2024         1/25/2024
# 9692    570254     2024-01-04    10/23/2024         2/12/2024
# 9714    570632     2024-01-11    10/29/2024          2/7/2024
#
#      Exit Date \nOr end of FY TEIDS\nECO_Entry_DATE AEPSi\nECO_Entry_DATE  \
# 4                  12/13/2023              7/9/2021             7/23/2021
# ...

# %%
df_eco_data['ECO_Entry_DATE'] = pd.to_datetime(df_eco_data['ECO_Entry_DATE'])
df_eco_data['ECO_Exit_DATE'] = pd.to_datetime(df_eco_data['ECO_Exit_DATE'])
# Out:
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\1679585227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eco_data['ECO_Entry_DATE'] = pd.to_datetime(df_eco_data['ECO_Entry_DATE'])
# C:\Users\jswin\AppData\Local\Temp\ipykernel_40692\1679585227.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eco_data['ECO_Exit_DATE'] = pd.to_datetime(df_eco_data['ECO_Exit_DATE'])

# %%
New_column = df_eco_data['ECO_Exit_DATE'] - df_eco_data['ECO_Entry_DATE']
New_column
# Out:
# 4       756 days
# 5      1277 days
# 7      1364 days
# 8      1099 days
# 17     1073 days
#           ...
# 9628    274 days
# 9638    321 days
# 9646    315 days
# 9692    293 days
# 9714    292 days
# Length: 4123, dtype: timedelta64[ns]

# %%
df_eco_data = pd.append(['New_column'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df_eco_data = pd.append(['New_column'])
#
# AttributeError: module 'pandas' has no attribute 'append'

# %%
df_eco_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4123 entries, 4 to 9714
# Data columns (total 15 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   CHILD_ID                                           4123 non-null   int64
#  1   ECO_Entry_DATE                                     4123 non-null   datetime64[ns]
#  2   ECO_Exit_DATE                                      4123 non-null   datetime64[ns]
#  3   Initial IFSP Date                                  4123 non-null   object
#  4   Exit Date
# Or end of FY                            4123 non-null   object
#  5   TEIDS
# ECO_Entry_DATE                               1189 non-null   object
#  6   AEPSi
# ECO_Entry_DATE                               260 non-null    object
#  7   AEPSi
# ECO_Exit_DATE                               260 non-null    object
#  8   BDI 3
# ...
